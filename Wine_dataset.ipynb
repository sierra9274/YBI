# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Cleaning the dataset

# %%
wine= pd.read_csv(r"C:\Users\KIIT\Desktop\AIML\wine quality\winequality-white.csv",delimiter=';')
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
wine.columns=['fixed acidity' ,'volatile acidity','citric acid','residual sugar' ,'chlorides' ,'free sulfur dioxide', 'total sulfur dioxide','density', 'pH','sulphates','alcohol','quality']
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
for i in wine.columns:
    print(i,':','\n',wine[i].unique(),'\n')
# Out:
# fixed acidity :
#  [ 7.    6.3   8.1   7.2   6.2   8.6   7.9   6.6   8.3   7.4   6.5   6.4
#   6.8   7.6   6.9   8.5   5.8   7.3   6.7   6.    7.1   6.1   7.5   9.8
#   5.5   5.9   7.8   5.7   8.2   5.6   5.2   8.4  10.2   7.7   5.3   5.4
#   9.1   5.    8.   10.    5.1   9.2   9.    8.8   8.7   4.8  10.3   9.4
#   9.6   9.3   8.9   9.7  10.7  14.2   9.9   9.5  11.8   4.6   6.15  4.5
#   7.15  6.45  4.2   4.9   4.7   3.8   4.4   3.9 ]
#
# volatile acidity :
#  [0.27  0.3   0.28  0.23  0.32  0.22  0.18  0.16  0.42  0.17  0.48  0.66
#  0.34  0.31  0.26  0.67  0.25  0.24  0.14  0.12  0.39  0.33  0.45  0.46
#  0.19  0.2   0.21  0.38  0.47  0.35  0.54  0.43  0.44  0.265 0.36  0.305
#  0.13  0.41  0.485 0.425 0.37  0.255 0.595 0.29  0.53  0.15  0.57  0.4
#  0.245 0.685 0.495 0.64  0.52  0.115 0.58  0.585 0.59  0.6   0.55  0.125
#  0.1   0.145 0.335 0.365 0.905 0.49  0.155 0.51  0.62  0.345 0.475 0.56
#  0.235 0.105 0.5   0.11  0.225 0.395 0.655 0.205 0.415 0.705 0.08  0.68
# ...

# %%
d=wine.describe(include='all')
d
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
wine.shape
# Out:
# (4898, 12)

# %%
wine['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %%
wine.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.600000          0.333250     0.336000        6.392500
# 4             7.129448          0.381227     0.304233        4.628221
# 5             6.933974          0.302011     0.337653        7.334969
# 6             6.837671          0.260564     0.338025        6.441606
# 7             6.734716          0.262767     0.325625        5.186477
# 8             6.657143          0.277400     0.326514        5.671429
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.054300            53.325000            170.600000  0.994884
# 4         0.050098            23.358896            125.279141  0.994277
# 5         0.051546            36.432052            150.904598  0.995263
# 6         0.045217            35.650591            137.047316  0.993961
# ...

# %% [markdown]
# # define y and x

# %%
y=wine['quality']

# %%
y.shape
# Out:
# (4898,)

# %%
y
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 4893    6
# 4894    5
# 4895    6
# 4896    7
# 4897    6
# Name: quality, Length: 4898, dtype: int64

# %%
x= wine.drop(['quality'],axis=1)
y=wine.quality

# %%
x.shape
# Out:
# (4898, 11)

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
x.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol
# 0      8.8
# 1      9.5
# 2     10.1
# 3      9.9
# 4      9.9

# %%
y.head()
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# Name: quality, dtype: int64

# %%
# Train Test Split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2529)

# %%
x_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 116             6.0              0.31         0.24             3.3      0.041
# 2423            7.2              0.24         0.29             3.0      0.036
# 4065            6.6              0.50         0.26            11.3      0.029
# 4893            6.2              0.21         0.29             1.6      0.039
# 4292            6.9              0.22         0.32             5.8      0.041
# ...             ...               ...          ...             ...        ...
# 4590            6.4              0.33         0.30             7.2      0.041
# 4476            6.0              0.20         0.38             1.3      0.034
# 3656            7.1              0.28         0.28             8.5      0.030
# 4836            6.7              0.50         0.36            11.5      0.096
# 2876            6.4              0.22         0.31            13.9      0.040
#
# ...

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3918, 11)
# (3918,)
# (980, 11)
# (980,)

# %% [markdown]
# # get x variables Standardized

# %%
# Standard scaler
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[ 3.31213971e+00, -2.79658506e-01,  1.73191486e+00, ...,
#         -1.65720747e+00, -5.19199404e-01, -1.27870543e-02],
#        [-5.27878688e-02,  1.68660803e+00, -4.30442083e-01, ...,
#         -8.62169957e-01, -6.07211487e-01,  6.90350572e-02],
#        [ 1.14897198e+00, -8.30318525e-02,  2.06458516e+00, ...,
#         -8.62169957e-01, -6.95223570e-01, -1.32194084e+00],
#        ...,
#        [-1.73525166e+00, -1.32188516e-01, -4.30442083e-01, ...,
#         -8.79316631e-04, -9.59259817e-01, -9.46091659e-02],
#        [-7.73843778e-01, -1.81345179e-01, -1.17895025e+00, ...,
#         -3.32144947e-01, -5.19199404e-01, -9.46091659e-02],
#        [ 6.73881161e-02, -1.36110510e+00,  4.01233664e-01, ...,
#         -1.06092933e+00,  4.48933505e-01,  7.23611950e-01]])

# %% [markdown]
# # Get model train

# %%
from sklearn.svm import SVC

# %%
svc=SVC()

# %%
svc.fit(x_train,y_train)
# Out:
# SVC()

# %% [markdown]
# # Get model Prediction

# %%
y_pred=svc.predict(x_test)

# %%
y_pred.shape
# Out:
# (1470,)

# %%
y_pred
# Out:
# array([6, 6, 6, ..., 6, 6, 6], dtype=int64)

# %% [markdown]
# # model evaluation

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[  0   0   1   3   0   0]
#  [  0   0   3  54   0   0]
#  [  0   0  59 366   0   0]
#  [  0   0  60 619   0   0]
#  [  0   0   9 248   0   0]
#  [  0   0   1  47   0   0]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         4
#            4       0.00      0.00      0.00        57
#            5       0.44      0.14      0.21       425
#            6       0.46      0.91      0.61       679
#            7       0.00      0.00      0.00       257
#            8       0.00      0.00      0.00        48
#
#     accuracy                           0.46      1470
#    macro avg       0.15      0.18      0.14      1470
# weighted avg       0.34      0.46      0.34      1470

# %% [markdown]
# # Get model Re-run with Two classes created for wine quality

# %%
# Wine quality 3,4,5 labelled as 0
# wine quality 6,7,8,9 labelled as 1

# %%
y=wine['quality'].apply(lambda y_values:1 if y_values>=6 else 0)

# %%
y.value_counts()
# Out:
# quality
# 1    3258
# 0    1640
# Name: count, dtype: int64

# %% [markdown]
# # get train test split

# %%
 from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2529)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3428, 11)
# (3428,)
# (1470, 11)
# (1470,)

# %% [markdown]
# # Get model train

# %%
from sklearn.svm import SVC

# %%
svc=SVC()

# %%
svc.fit(x_train,y_train)
# Out:
# SVC()

# %% [markdown]
# # Get model prediction

# %%
y_pred=svc.predict(x_test)

# %%
y_pred.shape
# Out:
# (1470,)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %% [markdown]
# # Get model evaluation

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 13 473]
#  [ 12 972]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.03      0.05       486
#            1       0.67      0.99      0.80       984
#
#     accuracy                           0.67      1470
#    macro avg       0.60      0.51      0.43      1470
# weighted avg       0.62      0.67      0.55      1470

# %% [markdown]
# # Get future predictions

# %%
wine_new=wine.sample(1)

# %%
wine_new
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2528            6.4              0.16         0.37             1.5      0.037
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2528                 27.0                 109.0  0.99345  3.38        0.5
#
#       alcohol  quality
# 2528      9.8        6

# %%
wine_new.shape
# Out:
# (1, 12)

# %%
X_new=wine_new.drop(['quality'],axis=1)

# %%
X_new=ss.fit_transform(X_new)

# %%
y_pred_new=svc.predict(X_new)

# %%
y_pred_new
# Out:
# array([1], dtype=int64)
